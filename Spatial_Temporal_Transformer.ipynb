# %% [markdown]
# <a href="https://colab.research.google.com/github/nies14/All-Colab-Notebooks/blob/main/Spatial_Temporal_Transformer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !which python # should return /usr/local/bin/python
# Out:
# /usr/local/bin/python

# %%
# !python --version
# Out:
# Python 3.7.12

# %%
# !echo $PYTHONPATH
# Out:
# /env/python

# %%
# %env PYTHONPATH=
# Out:
# env: PYTHONPATH=

# %%
# %%bash
# MINICONDA_INSTALLER_SCRIPT=Miniconda3-4.5.4-Linux-x86_64.sh
# MINICONDA_PREFIX=/usr/local
# wget https://repo.continuum.io/miniconda/$MINICONDA_INSTALLER_SCRIPT
# chmod +x $MINICONDA_INSTALLER_SCRIPT
# ./$MINICONDA_INSTALLER_SCRIPT -b -f -p $MINICONDA_PREFIX
# Out:
# PREFIX=/usr/local
# installing: python-3.6.5-hc3d631a_2 ...
# installing: ca-certificates-2018.03.07-0 ...
# installing: conda-env-2.6.0-h36134e3_1 ...
# installing: libgcc-ng-7.2.0-hdf63c60_3 ...
# installing: libstdcxx-ng-7.2.0-hdf63c60_3 ...
# installing: libffi-3.2.1-hd88cf55_4 ...
# installing: ncurses-6.1-hf484d3e_0 ...
# installing: openssl-1.0.2o-h20670df_0 ...
# installing: tk-8.6.7-hc745277_3 ...
# installing: xz-5.2.4-h14c3975_4 ...
# installing: yaml-0.1.7-had09818_2 ...
# installing: zlib-1.2.11-ha838bed_2 ...
# installing: libedit-3.1.20170329-h6b74fdf_2 ...
# installing: readline-7.0-ha6073c6_4 ...
# installing: sqlite-3.23.1-he433501_0 ...
# installing: asn1crypto-0.24.0-py36_0 ...
# installing: certifi-2018.4.16-py36_0 ...
# installing: chardet-3.0.4-py36h0f667ec_1 ...
# installing: idna-2.6-py36h82fb2a8_1 ...
# installing: pycosat-0.6.3-py36h0a5515d_0 ...
# installing: pycparser-2.18-py36hf9f622e_1 ...
# installing: pysocks-1.6.8-py36_0 ...
# ...

# %%
# !which conda # should return /usr/local/bin/conda
# Out:
# /usr/local/bin/conda

# %%
# !conda --version # should return 4.5.4
# Out:
# conda 4.5.4

# %%
# !python --version # now returns Python 3.6.5 :: Anaconda, Inc.
# Out:
# Python 3.6.5 :: Anaconda, Inc.

# %%
# %%bash
# conda install --channel defaults conda python=3.6 --yes
# conda update --channel defaults --all --yes
# Out:
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - conda
#     - python=3.6
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     idna-3.2                   |     pyhd3eb1b0_0          54 KB
#     certifi-2021.5.30          |   py36h06a4308_0         141 KB
#     pycosat-0.6.3              |   py36h27cfd23_0         107 KB
#     conda-package-handling-1.7.3|   py36h27cfd23_1         946 KB
#     libstdcxx-ng-9.1.0         |       hdf63c60_0         4.0 MB
#     pip-21.2.2                 |   py36h06a4308_0         2.1 MB
#     libffi-3.3                 |       he6710b0_2          54 KB
#     charset-normalizer-2.0.4   |     pyhd3eb1b0_0          33 KB
#     six-1.16.0                 |     pyhd3eb1b0_0          18 KB
#     cffi-1.14.6                |   py36h400218f_0         224 KB
# ...

# %%
import sys
sys.path
# Out:
# ['',
#  '/content',
#  '/env/python',
#  '/usr/lib/python37.zip',
#  '/usr/lib/python3.7',
#  '/usr/lib/python3.7/lib-dynload',
#  '/usr/local/lib/python3.7/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/local/lib/python3.7/dist-packages/IPython/extensions',
#  '/root/.ipython']

# %%
# !ls /usr/local/lib/python3.6/dist-packages

# %%
import sys
_ = (sys.path
        .append("/usr/local/lib/python3.6/site-packages"))

# %%
# !conda install --channel conda-forge featuretools --yes
# Out:
# done
# failed with initial frozen solve. Retrying with flexible solve.
# failed with repodata from current_repodata.json, will retry with next repodata source.
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - featuretools
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     bokeh-2.3.3                |   py36h5fab9bb_0         8.3 MB  conda-forge
#     ca-certificates-2021.5.30  |       ha878542_0         136 KB  conda-forge
#     certifi-2021.5.30          |   py36h5fab9bb_0         141 KB  conda-forge
#     click-7.1.2                |     pyh9f0ad1d_0          64 KB  conda-forge
#     cloudpickle-2.0.0          |     pyhd8ed1ab_0          24 KB  conda-forge
#     conda-4.10.3               |   py36h5fab9bb_2         3.1 MB  conda-forge
# ...

# %%
# !conda env update -f /content/drive/MyDrive/PoseFormer-main/poseformer.yml
# Out:
# done
# done
#
# ...
# cython-0.29.21       | 2.1 MB    | : 100% 1.0/1 [00:00<00:00,  1.73it/s]
# numpy-1.19.2         | 22 KB     | : 100% 1.0/1 [00:00<00:00,  8.16it/s]
# zstd-1.4.5           | 716 KB    | : 100% 1.0/1 [00:00<00:00,  5.88it/s]
# libstdcxx-ng-9.1.0   | 4.0 MB    | : 100% 1.0/1 [00:00<00:00,  1.55it/s]
# gmp-6.2.0            | 811 KB    | : 100% 1.0/1 [00:00<00:00,  4.29it/s]
# absl-py-0.10.0       | 169 KB    | : 100% 1.0/1 [00:00<00:00,  8.05it/s]
# openh264-2.1.1       | 1.5 MB    | : 100% 1.0/1 [00:00<00:00,  3.56it/s]
# harfbuzz-2.7.2       | 1.8 MB    | : 100% 1.0/1 [00:00<00:00,  2.83it/s]
# libxcb-1.14          | 610 KB    | : 100% 1.0/1 [00:00<00:00,  5.42it/s]
# idna-2.10            | 56 KB     | : 100% 1.0/1 [00:00<00:00, 21.02it/s]
# cairo-1.16.0         | 1.5 MB    | : 100% 1.0/1 [00:00<00:00,  3.00it/s]
# yacs-0.1.6           | 11 KB     | : 100% 1.0/1 [00:00<00:00, 24.87it/s]
# requests-2.24.0      | 54 KB     | : 100% 1.0/1 [00:00<00:00, 18.33it/s]
# ...

# %%
# %%shell
# eval "$(conda shell.bash hook)" # copy conda command to shell
# conda activate pose2
# python /content/drive/MyDrive/PoseFormer-main/run_poseformer.py -k cpn_ft_h36m_dbb -f 81 -c checkpoint --evaluate /content/drive/MyDrive/PoseFormer-main/checkpoint/detected81f.bin
# #python /content/drive/MyDrive/PoseFormer-main/run_poseformer.py -k cpn_ft_h36m_dbb -f 27 -lr 0.00004 -lrd 0.99
# Out:
# Loading dataset...
# Preparing /content/drive/MyDrive/PoseFormer-main/data...
# Loading 2D detections...
# INFO: Receptive field: 81 frames
# INFO: Trainable parameter count: 9602885
# Loading checkpoint /content/drive/MyDrive/PoseFormer-main/checkpoint/detected81f.bin
# INFO: Testing on 543344 frames
# Evaluating...
# tcmalloc: large alloc 1245782016 bytes == 0x559fe8b72000 @  0x7f3cf02c9b6b 0x7f3cf02e9379 0x7f3c3a31e74e 0x7f3c3a3207b6 0x7f3cb2a2b752 0x7f3cb2d16423 0x7f3cb2ceda57 0x7f3cb2d08b2c 0x7f3cb2ce4fda 0x7f3cb2ceda57 0x7f3cb2d08b2c 0x7f3cb2dd492d 0x7f3cb287e1cb 0x7f3cb2d16969 0x7f3cb2596770 0x7f3cb2ea616b 0x7f3cb2d90e3c 0x7f3cb43dacff 0x7f3cb2596770 0x7f3cb2ea616b 0x7f3cb2fe77cc 0x7f3cb286d4e8 0x7f3cb286e17a 0x7f3cb2f53d80 0x7f3cb2596770 0x7f3cb2ea616b 0x7f3cb2fe6b6c 0x7f3cb91fe21b 0x559f48b4365e 0x559f48bac43a 0x559f48b586bc
# ...
